# %% [markdown]
# ## Importing pandas

# %%
import pandas as pd

# %% [markdown]
# ## 2 Main datatypes

# %%
series = pd.Series(["BMW", "Toyata", "Honda"])

# %%
series
# Out:
# 0       BMW
# 1    Toyata
# 2     Honda
# dtype: object

# %% [markdown]
# ### 1. Series = 1-dimensional

# %%
colours = pd.Series(["Red", "Blue", "White"])
colours
# Out:
# 0      Red
# 1     Blue
# 2    White
# dtype: object

# %% [markdown]
# ### 2. DataFrame = 2-dimensinal

# %%
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    Red
# 1   Toyata   Blue
# 2    Honda  White

# %% [markdown]
# ## Importing data

# %%
car_sales = pd.read_csv("pandas_data/car-sales.csv")

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Exporting a dataframes

# %%
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
exported = pd.read_csv("exported-car-sales.csv")
exported
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Describe data
#
#     # Attribute -> car_sales.dtypes
#     # Function -> car_sales.to_csv()

# %% [markdown]
# ### Attribute

# %%
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_sales.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_columns = car_sales.columns
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ### Function

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
car_sales.mean()
# Out:
# C:\Users\gprab\AppData\Local\Temp\ipykernel_11320\4073448239.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   car_sales.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales["Doors"].mean()
# Out:
# 4.0

# %%
car_prices = pd.Series([3000, 1500, 111130, 4322])
car_prices.mean()
# Out:
# 29988.0

# %%
car_sales.max()
# Out:
# Make                Toyota
# Colour               White
# Odometer (KM)       213095
# Doors                    5
# Price            $9,700.00
# dtype: object

# %%
car_sales["Doors"].max()
# Out:
# 5

# %%
car_sales["Doors"].sum()
# Out:
# 40

# %% [markdown]
# ## Viewing and selecting data

# %% [markdown]
# ### head() and tail()

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
car_sales.tail(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ### .loc & .iloc

# %%
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0, 3, 9, 8, 3])

# %%
animals
# Out:
# 0      cat
# 3      dog
# 9     bird
# 8    panda
# 3    snake
# dtype: object

# %%
# loc refers to index

animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.loc[8]
# Out:
# 'panda'

# %%
car_sales.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# iloc refers to position

animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 9    bird
# dtype: object

# %%
car_sales.loc[:4]
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales["Colour"]
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales.Colour
# Out:
# 0    White
# 1      Red
# 2     Blue
# 3    Black
# 4    White
# 5    Green
# 6     Blue
# 7     Blue
# 8    White
# 9    White
# Name: Colour, dtype: object

# %%
car_sales["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Groupby

car_sales.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %% [markdown]
# ## Plotting Data

# %%
car_sales.plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <AxesSubplot:>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <AxesSubplot:>

# %%
car_sales["Price"].dtype
# Out:
# dtype('O')

# %%
# changing in csv file

car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "").astype(float)
# Out:
# C:\Users\gprab\AppData\Local\Temp\ipykernel_11320\1883114629.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   car_sales["Price"] = car_sales["Price"].str.replace("[\$\,\.]", "").astype(float)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   400000.0
# 1   Honda    Red          87899      4   500000.0
# 2  Toyota   Blue          32549      3   700000.0
# 3     BMW  Black          11179      5  2200000.0
# 4  Nissan  White         213095      4   350000.0
# 5  Toyota  Green          99213      4   450000.0
# 6   Honda   Blue          45698      4   750000.0
# 7   Honda   Blue          54738      4   700000.0
# 8  Toyota  White          60000      4   625000.0
# 9  Nissan  White          31600      4   970000.0

# %%
car_sales["Price"].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Manipulating Data

# %% [markdown]
# ### inplace

# %%
# we are changing inplace

car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4   400000.0
# 1   Honda    Red          87899      4   500000.0
# 2  Toyota   Blue          32549      3   700000.0
# 3     BMW  Black          11179      5  2200000.0
# 4  Nissan  White         213095      4   350000.0
# 5  Toyota  Green          99213      4   450000.0
# 6   Honda   Blue          45698      4   750000.0
# 7   Honda   Blue          54738      4   700000.0
# 8  Toyota  White          60000      4   625000.0
# 9  Nissan  White          31600      4   970000.0

# %%
# Reassigning
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  toyota  White         150043      4   400000.0
# 1   honda    Red          87899      4   500000.0
# 2  toyota   Blue          32549      3   700000.0
# 3     bmw  Black          11179      5  2200000.0
# 4  nissan  White         213095      4   350000.0
# 5  toyota  Green          99213      4   450000.0
# 6   honda   Blue          45698      4   750000.0
# 7   honda   Blue          54738      4   700000.0
# 8  toyota  White          60000      4   625000.0
# 9  nissan  White          31600      4   970000.0

# %%
car_sales["Colour"] = car_sales["Colour"].str.upper()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  toyota  WHITE         150043      4   400000.0
# 1   honda    RED          87899      4   500000.0
# 2  toyota   BLUE          32549      3   700000.0
# 3     bmw  BLACK          11179      5  2200000.0
# 4  nissan  WHITE         213095      4   350000.0
# 5  toyota  GREEN          99213      4   450000.0
# 6   honda   BLUE          45698      4   750000.0
# 7   honda   BLUE          54738      4   700000.0
# 8  toyota  WHITE          60000      4   625000.0
# 9  nissan  WHITE          31600      4   970000.0

# %%
car_sales["Make"].str.capitalize()
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       Bmw
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %% [markdown]
# ## Working with missing data

# %%
car_sales_missing = pd.read_csv("pandas_data/car-sales-missing-data.csv")

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].mean()
# Out:
# 92302.66666666667

# %% [markdown]
# ### Fill NaN

# %%
# Using inplace=True by default it is False

# car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing.dropna()
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
# Column from series
seats_column = pd.Series([5, 5, 5, 5, 5])

# New column called seats
car_sales["Seats"] = seats_column
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats
# 0  toyota  WHITE         150043      4   400000.0    5.0
# 1   honda    RED          87899      4   500000.0    5.0
# 2  toyota   BLUE          32549      3   700000.0    5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0
# 4  nissan  WHITE         213095      4   350000.0    5.0
# 5  toyota  GREEN          99213      4   450000.0    NaN
# 6   honda   BLUE          45698      4   750000.0    NaN
# 7   honda   BLUE          54738      4   700000.0    NaN
# 8  toyota  WHITE          60000      4   625000.0    NaN
# 9  nissan  WHITE          31600      4   970000.0    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats
# 0  toyota  WHITE         150043      4   400000.0    5.0
# 1   honda    RED          87899      4   500000.0    5.0
# 2  toyota   BLUE          32549      3   700000.0    5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0
# 4  nissan  WHITE         213095      4   350000.0    5.0
# 5  toyota  GREEN          99213      4   450000.0    5.0
# 6   honda   BLUE          45698      4   750000.0    5.0
# 7   honda   BLUE          54738      4   700000.0    5.0
# 8  toyota  WHITE          60000      4   625000.0    5.0
# 9  nissan  WHITE          31600      4   970000.0    5.0

# %%
# Column from python list

fuel_economy = [7.5, 9.2, 5.0, 9.6, 8.7, 6.8, 7.5, 8.4, 5.6, 7.1]
car_sales["Fuel per 100KM"] = fuel_economy
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1

# %%
car_sales["Total fuel used (Ltr)"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Total fuel used (Ltr)
# 0              11253.225
# 1               8086.708
# 2               1627.450
# 3               1073.184
# 4              18539.265
# ...

# %%
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Total fuel used (Ltr)  Number of wheels
# 0              11253.225                 4
# 1               8086.708                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Total fuel used (Ltr)  Number of wheels  Passed road safety
# 0              11253.225                 4                True
# ...

# %%
car_sales.dtypes
# Out:
# Make                      object
# Colour                    object
# Odometer (KM)              int64
# Doors                      int64
# Price                    float64
# Seats                    float64
# Fuel per 100KM           float64
# Total fuel used (Ltr)    float64
# Number of wheels           int64
# Passed road safety          bool
# dtype: object

# %%
car_sales = car_sales.drop("Total fuel used (Ltr)", axis=1)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales.sample(frac=0.5) # 50% data
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4  400000.0    5.0             7.5
# 7   honda   BLUE          54738      4  700000.0    5.0             8.4
# 5  toyota  GREEN          99213      4  450000.0    5.0             6.8
# 9  nissan  WHITE          31600      4  970000.0    5.0             7.1
# 2  toyota   BLUE          32549      3  700000.0    5.0             5.0
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 7                 4                True
# 5                 4                True
# 9                 4                True
# 2                 4                True

# %%
car_sales_shuffled = car_sales.sample(frac=1) # 100% data

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
#
#    Number of wheels  Passed road safety
# 3                 4                True
# 4                 4                True
# 9                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
# Only select 20% of data

car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors     Price  Seats  Fuel per 100KM  \
# 8  toyota  WHITE          60000      4  625000.0    5.0             5.6
# 0  toyota  WHITE         150043      4  400000.0    5.0             7.5
#
#    Number of wheels  Passed road safety
# 8                 4                True
# 0                 4                True

# %%
car_sales_shuffled.reset_index(drop=True, inplace=True)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 1  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 2  nissan  WHITE          31600      4   970000.0    5.0             7.1
# 3   honda    RED          87899      4   500000.0    5.0             9.2
# 4  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 8  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 9   honda   BLUE          54738      4   700000.0    5.0             8.4
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  WHITE         150043      4   400000.0    5.0             7.5
# 1   honda    RED          87899      4   500000.0    5.0             9.2
# 2  toyota   BLUE          32549      3   700000.0    5.0             5.0
# 3     bmw  BLACK          11179      5  2200000.0    5.0             9.6
# 4  nissan  WHITE         213095      4   350000.0    5.0             8.7
# 5  toyota  GREEN          99213      4   450000.0    5.0             6.8
# 6   honda   BLUE          45698      4   750000.0    5.0             7.5
# 7   honda   BLUE          54738      4   700000.0    5.0             8.4
# 8  toyota  WHITE          60000      4   625000.0    5.0             5.6
# 9  nissan  WHITE          31600      4   970000.0    5.0             7.1
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales["Colour"] = car_sales["Colour"].str.capitalize()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  White         150043      4   400000.0    5.0             7.5
# 1   honda    Red          87899      4   500000.0    5.0             9.2
# 2  toyota   Blue          32549      3   700000.0    5.0             5.0
# 3     bmw  Black          11179      5  2200000.0    5.0             9.6
# 4  nissan  White         213095      4   350000.0    5.0             8.7
# 5  toyota  Green          99213      4   450000.0    5.0             6.8
# 6   honda   Blue          45698      4   750000.0    5.0             7.5
# 7   honda   Blue          54738      4   700000.0    5.0             8.4
# 8  toyota  White          60000      4   625000.0    5.0             5.6
# 9  nissan  White          31600      4   970000.0    5.0             7.1
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x / 2)
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors      Price  Seats  Fuel per 100KM  \
# 0  toyota  White        75021.5      4   400000.0    5.0             7.5
# 1   honda    Red        43949.5      4   500000.0    5.0             9.2
# 2  toyota   Blue        16274.5      3   700000.0    5.0             5.0
# 3     bmw  Black         5589.5      5  2200000.0    5.0             9.6
# 4  nissan  White       106547.5      4   350000.0    5.0             8.7
# 5  toyota  Green        49606.5      4   450000.0    5.0             6.8
# 6   honda   Blue        22849.0      4   750000.0    5.0             7.5
# 7   honda   Blue        27369.0      4   700000.0    5.0             8.4
# 8  toyota  White        30000.0      4   625000.0    5.0             5.6
# 9  nissan  White        15800.0      4   970000.0    5.0             7.1
#
#    Number of wheels  Passed road safety
# 0                 4                True
# 1                 4                True
# 2                 4                True
# ...
